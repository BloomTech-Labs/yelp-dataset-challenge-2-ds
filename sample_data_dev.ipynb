# %% [markdown]
# ## Exploring Dask Framework & Client
#
# Building high performance data processing pipeline for sampling.  Code might be useful for later implementations, exploration

# %%
# Some important dependencies
# !pip install --upgrade pip
# !pip install python-decouple pandas pyarrow

# %% [markdown]
# ### Start Dask Client for Dashboard
#
# **Source** https://examples.dask.org/dataframe.html

# %%
from dask.distributed import Client, progress
client = Client(n_workers=4, threads_per_worker=2, memory_limit='2GB')

# %%
# Show client stats (dashboard)
client
# Out:
# <Client: 'tcp://127.0.0.1:40005' processes=4 threads=8, memory=8.00 GB>

# %% [markdown]
# ### Download S3 Data to dask dataframe

# %%
###Connect to S3###
from awstools.awstools import s3

def get_bucket(bucket_name = 'yelp-data-shared-labs18'):
    return s3.Bucket(bucket_name)

# %%
import dask
import dask.dataframe as dd
import pandas as pd
import os

def load_json(filename, npartitions=4):
    """
    Download json file and load into dask dataframe.
    
    Parameters
    ----------
    
    """
    filepath = os.path.join(os.getcwd(), filename)
    try:
        dask_df = dd.read_json(filepath)
        return dask_df
    except:
        raise

# %%
# Manually download file
bucket = get_bucket()
filename='sample_data/tip.parquet'
bucket.get(filename, 'tip.parquet')

# %%
df = load_json(filename='business.json')

# %%
display(type(df), df.head())
# Out:
# dask.dataframe.core.DataFrame
#               business_id                             name  \
# 0  1SWheh84yJXfytovILXOAQ       Arizona Biltmore Golf Club
# 1  QXAEGFB4oINsVuTFxEYKFQ       Emerald Chinese Restaurant
# 2  gnKjwL_1w79qoiV3IC_xQQ      Musashi Japanese Restaurant
# 3  xvX2CttrVhyG2z1dFg_0xw  Farmers Insurance - Paul Lorenz
# 4  HhyxOkGAM07SRYtlQ4wMFQ              Queen City Plumbing
#
#                           address         city state postal_code   latitude  \
# 0     2818 E Camino Acequia Drive      Phoenix    AZ       85016  33.522143
# 1            30 Eglinton Avenue W  Mississauga    ON     L5R 3E7  43.605499
# 2       10110 Johnston Rd, Ste 15    Charlotte    NC       28210  35.092564
# 3   15655 W Roosevelt St, Ste 237     Goodyear    AZ       85338  33.455613
# 4  4209 Stuart Andrew Blvd, Ste F    Charlotte    NC       28217  35.190012
#
#     longitude  stars  review_count  is_open  \
# 0 -112.018481    3.0             5        0
# 1  -79.652289    2.5           128        1
# 2  -80.859132    4.0           170        1
# 3 -112.395596    5.0             3        1
# 4  -80.887223    4.0             4        1
#
#                                           attributes  \
# 0                           {'GoodForKids': 'False'}
# 1  {'RestaurantsReservations': 'True', 'GoodForMe...
# 2  {'GoodForKids': 'True', 'NoiseLevel': 'u'avera...
# 3                                               None
# 4  {'BusinessAcceptsBitcoin': 'False', 'ByAppoint...
#
#                                           categories  \
# 0                                  Golf, Active Life
# 1  Specialty Food, Restaurants, Dim Sum, Imported...
# 2                  Sushi Bars, Restaurants, Japanese
# 3                      Insurance, Financial Services
# 4  Plumbing, Shopping, Local Services, Home Servi...
#
#                                                hours
# 0                                               None
# 1  {'Monday': '9:0-0:0', 'Tuesday': '9:0-0:0', 'W...
# 2  {'Monday': '17:30-21:30', 'Wednesday': '17:30-...
# 3  {'Monday': '8:0-17:0', 'Tuesday': '8:0-17:0', ...
# 4  {'Monday': '7:0-23:0', 'Tuesday': '7:0-23:0', ...

# %%
df.tail()
# Out:
#                    business_id                   name                address  \
# 192604  nqb4kWcOwp8bFxzfvaDpZQ     Sanderson Plumbing
# 192605  vY2nLU5K20Pee-FdG0br1g               Chapters     17440 Yonge Street
# 192606  MiEyUDKTjeci5TMfxVZPpg         Phoenix Pavers        21230 N 22nd St
# 192607  zNMupayB2jEHVDOji8sxoQ  Beasley's Barber Shop         4406 E Main St
# 192608  c1f_VAX1KIK8-JoVhjbYOw         Oriental Relax  3735 S Las Vegas Blvd
#
#                    city state postal_code   latitude   longitude  stars  \
# 192604  North Las Vegas    NV       89032  36.213732 -115.177059    5.0
# 192605        Newmarket    ON     L3Y 6Y9  44.052658  -79.481850    4.5
# 192606          Phoenix    AZ       85024  33.679992 -112.035569    4.5
# 192607             Mesa    AZ       85205  33.416137 -111.735743    4.5
# 192608        Las Vegas    NV       89109  36.107267 -115.171920    4.0
#
#         review_count  is_open  \
# 192604             9        1
# 192605             3        1
# 192606            14        1
# 192607            15        1
# 192608             3        0
#
#                                                attributes  \
# 192604             {'BusinessAcceptsCreditCards': 'True'}
# 192605  {'RestaurantsPriceRange2': '2', 'BikeParking':...
# 192606  {'BusinessAcceptsCreditCards': 'True', 'ByAppo...
# 192607  {'RestaurantsPriceRange2': '1', 'BusinessAccep...
# 192608  {'BikeParking': 'False', 'RestaurantsPriceRang...
#
#                                                categories  \
# 192604  Water Purification Services, Water Heater Inst...
# 192605               Books, Mags, Music & Video, Shopping
# 192606  Home Services, Contractors, Landscaping, Mason...
# 192607                             Beauty & Spas, Barbers
# 192608                             Massage, Beauty & Spas
#
#                                                     hours
# 192604  {'Monday': '0:0-0:0', 'Tuesday': '0:0-0:0', 'W...
# 192605                                               None
# 192606  {'Monday': '7:0-15:0', 'Tuesday': '7:0-15:0', ...
# 192607  {'Tuesday': '8:30-17:30', 'Wednesday': '8:30-1...
# 192608  {'Monday': '10:0-0:0', 'Tuesday': '10:0-0:0', ...

# %%
###Get/Transcribe File Data###
file_list = [
    ('business.json', 132),
    ('user.json', 2300),
    ('review.json', 5000),
    ('photo.json', 25),
    ('checkin.json', 390),
    ('tip.json', 234),
]


# Set max file size for output
max_file_size = 20  # MB


# Calculate fraction of dataset to capture
fraction_list = [(x[0], max_file_size/x[1]) for x in file_list]


print(fraction_list)

# %% [markdown]
# So far, Pandas will work as a drop in Dask.  I think staying with Dask is a good idea temporarily in the event we want to sample with computation (future feature generation via submit(apply_func, dataframe).

# %% [markdown]
# ## Generate Sample Data
#
# Create sampling procedure to get subset of data.  Early version will be simple random sample, but some time series analysis may be useful for future samples.

# %%
def sample_data(dataframe, fraction, filename=None):
    """
    Return sampled dataframe or save as parquet file.
    """
    if filename is None:
        return dataframe.sample(frac=fraction, replace=False).compute()
    dataframe.sample(frac=fraction, replace=False).compute().to_parquet(
        filename
    )

# %%
sdf = sample_data(df, 0.2)
sdf.head()
# Out:
#                    business_id                             name  \
# 127621  4B6HGu5C68dfUk5_N2lbYg  Porta Via Restaurant & Catering
# 65146   mS_Vorll2cVmux4ZNk7Apw        North Valley Eye Care, PC
# 16932   Fa0eq4Gwl8Tuc168Sm1rpA                      ISM Raceway
# 97928   7TLrRPcU_fPPESzEXhrxmA                      Food Basics
# 4032    PXljOYf3NJpIhJ9dQuKFhg            Irpinia Kitchen Sales
#
#                                           address           city state  \
# 127621          5399 Eglinton Avenue W, Suite 104        Toronto    ON
# 65146                2525 W Carefree Hwy, Ste 116        Phoenix    AZ
# 16932                        7602 S Avondale Blvd       Avondale    AZ
# 97928                        5559 Dundas Street W      Etobicoke    ON
# 4032    1280 Castlefield Avenue, 278 Newkirk Road  Richmond Hill    ON
#
#        postal_code   latitude   longitude  stars  review_count  is_open  \
# 127621     M9C 5K6  43.663030  -79.589617    4.5            38        1
# 65146        85085  33.797942 -112.114679    5.0            34        1
# 16932        85323  33.374918 -112.311246    4.0            41        1
# 97928      M9B 1B9  43.628265  -79.550149    3.0             4        1
# 4032       L4C 3G7  43.699411  -79.459226    2.5             3        0
#
#                                                attributes  \
# 127621  {'HasTV': 'False', 'RestaurantsAttire': 'u'cas...
# 65146   {'AcceptsInsurance': 'True', 'BusinessAcceptsC...
# 16932                             {'GoodForKids': 'True'}
# 97928   {'RestaurantsTakeOut': 'False', 'Caters': 'Fal...
# 4032                                                 None
#
#                                                categories  \
# 127621  Sandwiches, Salad, Event Planning & Services, ...
# 65146                      Health & Medical, Optometrists
# 16932      Race Tracks, Active Life, Arts & Entertainment
# 97928                                       Grocery, Food
# 4032              Kitchen & Bath, Shopping, Home & Garden
#
#                                                     hours
# 127621  {'Monday': '11:0-15:0', 'Tuesday': '11:0-15:0'...
# 65146   {'Monday': '8:0-17:30', 'Tuesday': '8:0-17:30'...
# 16932   {'Monday': '8:0-17:0', 'Tuesday': '8:0-17:0', ...
# 97928   {'Monday': '8:0-22:0', 'Tuesday': '8:0-22:0', ...
# 4032                                                 None

# %%
# business.json attribute structure will not save to parquet natively.  Need to flatten/expand
# sdf.to_parquet('sample_business.parquet')
sdf.to_json('sample_business.json', orient='records')

# %% [markdown]
# **daskdataframe.sample()** returns a pandas DataFrame!

# %%
sample_data(df, 0.2, 'sample_business.json')

# %% [markdown]
# ### Read from parquet or JSON (into pandas, now that we have a smaller file)

# %%
import pandas as pd
import os

filename = 'sample_users.parquet'
filepath = os.path.join(os.getcwd(), 'db_api', filename)

sample_data = pd.read_parquet(filepath)
# sample_data = pd.read_json(filepath)
sample_data.head()
# Out:
#                         user_id          name  review_count  \
# 1531760  ULGM_WSrSHk7SPfOngN6jA         Allyn            33
# 1125613  YHSvgBH1kdiOzreTr7RJAA  Allam Dinesh             1
# 894988   aZqHLzOGv6G20Fvw8l7NXw             J            30
# 560230   E-_4sIgh4YNne_q4Mj5HBw         Shawn             1
# 843815   qn4Zc-MaITdhzaEq-Zl6oA      Jennifer            30
#
#                yelping_since  useful  funny  cool elite  \
# 1531760  2014-04-16 14:07:29      46      8     3
# 1125613  2015-05-03 22:43:58       3      1     1
# 894988   2010-02-05 21:26:53      34      5     9
# 560230   2010-09-04 18:48:46       0      0     0
# 843815   2010-07-15 00:51:43      24      5    10
#
#                                                    friends  fans  ...  \
# 1531760     lYp818T-xh8Ss79To5Azhw, OpDDS05v_O3HSnIxCFN2Wg     1  ...
# 1125613                                               None     0  ...
# 894988      3z7E1Gg001_1YdZZYDnO2A, HF5tvVj7cWWwth2CRnkKcA     0  ...
# 560230                              jUbRgQeWSm4G4tjLB-59hQ     0  ...
# 843815   gn5fwkEcKR4uF9wwVr2fCA, 0yfhwU4AhU7ev90sNzVrww...     2  ...
#
#          compliment_more  compliment_profile  compliment_cute  \
# 1531760                0                   0                0
# 1125613                0                   0                0
# 894988                 0                   0                0
# 560230                 0                   0                0
# 843815                 0                   0                0
#
#          compliment_list  compliment_note  compliment_plain  compliment_cool  \
# 1531760                0                4                 0                0
# 1125613                0                0                 0                0
# 894988                 0                1                 0                1
# 560230                 0                0                 0                0
# 843815                 0                0                 1                0
#
#          compliment_funny  compliment_writer  compliment_photos
# 1531760                 0                  1                  0
# 1125613                 0                  0                  0
# 894988                  1                  0                  1
# 560230                  0                  0                  0
# 843815                  0                  0                  0
#
# [5 rows x 22 columns]

# %%
# Save to bucket
from awstools.awstools import s3

bucket = s3.Bucket(bucket_name='yelp-data-shared-labs18')

# %%
local_filename = 'sample_business.json'
save_name = 'sample_data/sample_business.json'

bucket.save(file_name=local_filename, object_name=save_name)
# Out:
# sample_business.json  27626611 / 27626611.0  (100.00%)

# %% [markdown]
# ### List Bucket Contents
#
# Emulate directory structure from s3 flat storage.

# %%
for key in s3.get_bucket_keys(bucket_name = 'yelp-data-shared-labs18'):
    print(key)

# %%
bucket = s3.Bucket(bucket_name='yelp-data-shared-labs18')
bucket.contents

# %%
bucket.dir(all=False)

# %%
for parq in bucket.find(suffix="parquet"):
    print(parq)

# %% [markdown]
# ### DateTime Conversion
#
# DateTime fields must be regenerated from JSON input as that information does not carry.
#
# Tips, Reviews, Users, and Checkins all have a datetime stamp

# %%
from datetime import datetime

time_str = '2014-04-16 poop14:07:29'

try:
    datetime_object = datetime.fromisoformat(time_str)
except ValueError:
    print('Value Error')
    print(datetime.fromisoformat('1969-01-01'))
    raise
print(datetime_object)
# Out:
# Value Error
# 1969-01-01 00:00:00
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-ea954cd9a000> in <module>
#       4
#       5 try:
# ----> 6     datetime_object = datetime.fromisoformat(time_str)
#       7 except ValueError:
#       8     print('Value Error')
#
# ValueError: Invalid isoformat string: '2014-04-16 poop14:07:29'
